# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aebtehaj/Hydrologic-Design_Notebook/blob/main/Chapter6.ipynb)

# %% [markdown]
# <a id="0"></a>
# <div style="text-align: center; color: #1877F2">
#   <h1>Hydrologic Design 4501</h1>
# </div>
#
# <div style="text-align: center; font-weight: bold;">
#   Chapter 6: Surface Water and Runoff Processes
# </div>
#
# <div style="text-align: center; margin-bottom: 0.5em;">
#   Mohammadali Olyaei and Ardehsir Ebtehaj
# </div>
#
# <div style="text-align: center; font-weight: bold;">
#   University of Minnesota
# </div>
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6.gif" alt="Title" style="width: auto; height: 250px;">
# </div>

# %% [markdown]
# <a id="1"></a>
# # 1- Watersheds and Runoff

# %% [markdown]
# A **waterhsed**, a **catchment** or a **drainage basin**, are three synonymous terms that define a locus of points on the Earth's surface that drain precipitation water to a single point called the **wathershed outlet**.
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F1a.png" alt="Figure 1a" style="width: auto; height: 250px;">
#   <img src="Figures/Ch6/Ch6F1b.png" alt="Figure 1b" style="width: auto; height: 250px;">
# </div>
#
# <p style="text-align: center;">Left: Schematic of precipitation in a watershed flowing the precipitation water towards the outlet point. Right: A schematic of how watersheds are nested and watershed size varies depending on the basin outlet selected (right, credit: Marsh, 1998, p. 170)</p>

# %% [markdown]
# # 2- Basics of Surface Runoff
#
# During a rainfall event, there are two types of water storages:
#
# - **Detention Storages:** Short-term storages that are depleted by overland flows and infiltration.
# - **Retention Storages:** Long-term storages that are depleted by evaporation.
#
#
# **Surface runoff or overland flow** is defined as the portion of rainfall, snowmelt, and/or irrigation water that **runs over the soil surface** toward the stream network rather than infiltrating into the soil. The definition of runoff also may include the **interflow and/or return flow**, which together with the surface runoff make up the volume of **stormwater** or **total runoff**. The **return flow** is referred to the shallow subsurface lateral infiltrated flow of water that returns back to the surface.
#
# During a precipitation event, the detention storages begin to fill out and water starts to flow over land surfaces. Overland flows join together over a hillslope and form more concentrated flows that channelize the underlying soil creating the so-called channel or **stream network**. Several channel networks eventually joint and drain into the main stream and generate the **streamflow**.
#
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F2a.png" alt="Figure 2a" style="width: auto; height: 250px;">
#   <img src="Figures/Ch6/Ch6F2b.png" alt="Figure 2b" style="width: auto; height: 250px;">
# </div>
#
# <p style="text-align: center;">A schematic of the main runoff components in the absence (left) or presence (right) of snowmelt.</p>
#
# The flow that you see in a stream or river typically consists of three main hydrologic fluxes that we briefly covered in Chapter 1. These fluxes are: **overland flow**, **return flow**, and **baseflow** as shown in the above Figure. The overland flow component can be split into two categories:
#
# - **Hortonian overland flow**: The overland flow that occurs when precipitation rate is greater than infiltration capacity.  It is also called **infiltration excess** runoff.
# - **Saturated overland flow**: The overland flow that occurs when soil becomes saturated from below due to rise in the groundwater table. The produced runoff through this mechanism is also called **saturation excess** runoff.
#
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F3a.gif" alt="Figure 3a" style="width: auto; height: 250px;">
#   <img src="Figures/Ch6/Ch6F3b.gif" alt="Figure 3b" style="width: auto; height: 250px;">
#   <img src="Figures/Ch6/Ch6F3c.gif" alt="Figure 3c" style="width: auto; height: 250px;">
# </div>
#
# <p style="text-align: center;">Infiltration exceeds precipitation (left), Hortonian overland flow (middle) and Saturated overland flow (right).</p>
#
# As we discussed, the infiltration rate is the water flux that enters the soil at the surface. It is often expressed as depth of water per time, for example, 10 millimeters per hour.
#
# If precipitation rate is much higher than the infiltration capacity, overland flow occurs immediately after the onset of precipitation. **Infiltration excess** is commonly observed with short-duration intense rainfall. It also occurs most often over land surfaces with high clay content or where the surface has been altered by soil compaction, urbanization, or fire.
#
# However, when precipitation rate is less than or equal to infiltration capacity, no overland surface runoff occurs. For prolonged precipitation event, the water table may rise and produce the saturated overland flow from below. It is most common with long-duration, light-to-moderate rainfall, or because of successive precipitation and or snowmelt events at upstream. Saturation excess runoff can occur anywhere, when the soil is saturated from below. It is the most common runoff generation mechanism in humid climates with gently sloped or flat basins. The saturate overland flow and return flow often occur near the stream channels, where the groundwater depth is often shallower and it rises quickly in response to infiltration -- called **groundwater ridges**.
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F4a.png" alt="Figure 4a" style="width: auto; height: 250px;">
#   <img src="Figures/Ch6/Ch6F4b.png" alt="Figure 4b" style="width: auto; height: 250px;">
# </div>
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F5.png" alt="Figure 5" style="width: auto; height: 200px;">
# </div>
#
# <p style="text-align: center;">A schematic of overland versus saturation excess runoff over the hillslope and near the channel.</p>

# %% [markdown]
# # 3- Streamflow Hydrograph
#
# The **streamflow hydrograph** is the time series of flow rate at a specific location on a stream. These measurements are typically captured at stream gauges, which measure flow rate based on river stage and a flow rating curve.  The USGS is the primary source of stream gauge data in U.S.
#
# For simplicity, we will categorize two different hydrographs typically analyzed based on the time scale of interest.  An **annual hydrograph** focuses on the flow over a time period of a year at daily time steps (shown below).  A **storm hydrograph** focuses on the flow corresponding to a precipitation event for time periods ranging from hours to weeks depending on the watershed size and storm duration.
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F6a.png" alt="Figure 6a" style="width: auto; height: 250px;">
#   <img src="Figures/Ch6/Ch6F6b.png" alt="Figure 6b" style="width: auto; height: 250px;">
# </div>
#
# <p style="text-align: center;">An example of an annual (left) and storm (right) hydrograph for Vermillion River near Empire, MN. (Credit: USGS).</p>
#
#
# There are multiple characteristics of a basin and its river network that determine the shape of the outflow hydrograph including:
# - (a) size of the drainage basin
# - (b) slope
# - (c) hydraulic roughness
# - (d) natural and channel storages
# - (e) stream length
# - (f) channel density
# - (g) antecedent soil moisture
# - (h) other factors such as land cover
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F7.png" alt="Figure 7" style="width: auto; height: 250px;">
# </div>
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F8a.png" alt="Figure 8a" style="width: auto; height: 250px;">
#   <img src="Figures/Ch6/Ch6F8b.png" alt="Figure 8b" style="width: auto; height: 250px;">
#   <img src="Figures/Ch6/Ch6F8c.png" alt="Figure 8c" style="width: auto; height: 250px;">
# </div>
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F8d.png" alt="Figure 8d" style="width: auto; height: 250px;">
# </div>
#
# <p style="text-align: center;">The effects of basin characteristics on the flood hydrograph (Masch 1984)</p>
#
# The **dynamics of precipitation events** also affects the shape of the hydrograph.
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F9.png" alt="Figure 9" style="width: 600px; height: auto;">
# </div>
#
# <p style="text-align: center;">Effects of the shape of the rainfall hyetograph, storm size and movement on the shape of the streamflow hydrograph.</p>

# %% [markdown]
# ## 3-1 Hydrograph Components
#
# Hydrographs are typically divided into two components for analysis. The **baseflow**, which is the long-term contribution of groundwater flow to a stream hydrograph and the **direct runoff**, which is the portion of the hydrograph that is in response to an **excess rainfall** of an event and is also referred to as **quick flow**.
#
# The storm hydrograph can be divided into a few segments as follows:
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F10.png" alt="Figure 10" style="width: 400px; height: auto;">
# </div>
#
# <p style="text-align: center;">Main components of a storm hydrograph (McKerchar 1993). Note that the saturated overland flow and interflow (return flow) are the main components of the direct runoff hydrograph</p>

# %% [markdown]
# ## 3-2 Baseflow Separation
# Three different methods for basflow separation are:
# - **Straight line method**: Draw a line from the beginning of the rising limb to end of the falling limb, where the recession starts.
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F11.png" alt="Figure 11" style="width: 500px; height: auto;">
# </div>
#
# <p style="text-align: center;">Components of the streamflow hydrograph: (1-2) <strong>baseflow recession</strong>, (2-3) <strong>rising limb</strong>, (3-5) <strong>crest segment</strong>, (4) <strong>peak flow</strong>, (5-6) <strong>falling limb</strong>, and (6-7) <strong>baseflow recession</strong>. The straight line method is used for baseflow septation. At the beginning of the falling limb is an inflection point (5), where the direction of the curvature changes.</p>
#
# - **Fixed-base method**: Draw a tangent line from the pre-event recession curve to the peak time and then connect it to a point on the hydrograph that the surface runoff is assumed to be negligible.
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F12.png" alt="Figure 12" style="width: 500px; height: auto;">
# </div>
#
# <p style="text-align: center;">Fixed-based method for baseflow septation</p>
#
#
# - **Variable-slope method**: Draw a tangent line from the pre-event recession curve to the peak time and a tangent line from the post-event recession curve to the inflection point of the falling limb.  A straightline is drawn between the peak discharge and inflection point.
#
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F13.png" alt="Figure 13" style="width: 500px; height: auto;">
# </div>
#
# <p style="text-align: center;">Variable slope method for baseflow septation</p>

# %% [markdown]
# ## 3-3 Excess Rainfall and Direct Runoff
#
# The **direct runoff** determined from a hydrograph does not exactly correspond to the volume of precipitation delivered over the basin since there are losses to storages. Therefore, when predicting direct runoff from precipitation inputs, we divide the rainfall hayetograph into:
#
# - **Excess Rainfall**: The amount of rainfall that is neither retained on the land surface nor percolate into the groundwater as a recharge flow. This rainfall volume flows across the watershed as **surface runoff or return flow** to generate **direct runoff**. The excess rainfall is also known as the **effective rainfall**.
# - **Abstraction**: The rainfall that is absorbed primarily by infiltration followed by groundwater recharge as well as interception by vegetation and surface storages. The **excess rainfall hyetograph (ERH) is equal to the total rainfall minus total abstraction**.
#
# The conceptual relationships of rainfall, infiltration rate, and excess rainfall are shown in the following figures.
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F14.png" alt="Figure 14" style="width: 500px; height: auto;">
# </div>
# <p style="text-align: center;">The concept of rainfall excess, which is the difference between the actual rainfall hyetograph and losses largely due to the infiltration. Generally, we either assume a constant rate  (red line) or a time varying infiltration (black) rate in computation of the excess rainfall hayetograph (ERH).</p>
#
# Approximating **excess or effective rainfall** is crucial for **stomrwater managment** and **prediction of streamflow** for future rainfall events. There are different methods for determining effective rainfall depending on **whether streamflow data is available or not**.

# %% [markdown]
# ### 3-3-1 Excess Rainfall using Streamflow Data
#
# To determine the **excess rainfall hyetograph (ERH)**, the first step is to separate the baseflow from the **direct runoff hydrograph (DRH)**. One of the most common methods for obtaining the ERH is the $\phi$-Index method.  This method assumes a constant rate of abstraction throughout the storm event and is calculated as follows:
#
# $$r_d =\sum_{m=1}^M \left(R_m -\phi \Delta t\right)=\sum_{m=1}^M R_m -M\phi \Delta t$$
#
# where $r_d \;\left\lbrack \textrm{mm}\right\rbrack$ is the excess runoff depth, $R_{m\;} \;\left\lbrack \textrm{mm}\right\rbrack$ is the observed rainfall depth over a time interval $\Delta t\;$ with a decreasing order $R{\;}_1 >R{\;}_2 >\ldotp \ldotp \ldotp$, where $M$ is the number of rainfall pulses that contribute to direct runoff, and $\phi \;\left\lbrack \textrm{mm}{\;\textrm{hr}}^{-1} \right\rbrack$ is called the constant **abstraction rate**.
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F15.png" alt="Figure 15" style="width: 800px; height: auto;">
# </div>
#
# <p style="text-align: center;">
# A schematic representation of the $\phi$-index method. The $Q_i$ is the stremaflow minus basefloe and thus $r_d$ are the results of direct runoff, which is obtained by subtracting the baseflow from the total observed flow</p>
#
# The process consists of checking the above equation for descending values of $R_m$ until a positive $\phi$ value is achieved.  Then double check that the depth of excess rainfall equals the depth of direct runoff.

# %% [markdown]
# ---
# **Example Problem 6.1:** We have rge following information of a rainfall storm over a watershed area of 7.03 ${\mathrm{[mile^2]}}$ with a baseflow of 400 [cfs]:
#
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F16.png" alt="Figure 16" style="width: 700px; height: auto;">
# </div>

# %% [markdown]
# **Solution:**
#
# $Q_i$ is obtained by subtracting the baseflow 400 $\left\lbrack \textrm{cfs}\right\rbrack$ from the streemflow (column 3) data resulting the data in column 6
#
# $$V_{\textrm{runoff}} =\sum_{i=1}^{11} Q{\;}_n \Delta t=43,500\;\left\lbrack \textrm{cfs}\right\rbrack \times \;\frac{1}{2}\;\left\lbrack \textrm{hr}\right\rbrack \times \;3600\;\left\lbrack \frac{\mathrm{s}}{\textrm{hr}}\right\rbrack =7\ldotp 839\times \;{10}^7 \;\left\lbrack {\textrm{ft}}^3 \right\rbrack$$
#
# Total amount of excess rainfall uniformly distributed over the watershed is
#
# $$r_d =\frac{V_{\textrm{runoff}} }{\textrm{watershed}\;\textrm{area}}=\frac{7\ldotp 84\times \;{10}^7 \;\left\lbrack {\textrm{ft}}^3 \right\rbrack }{7\ldotp 03\times \;5280\;\left\lbrack {\textrm{ft}}^2 \right\rbrack }=4\ldotp 8\;\left\lbrack \textrm{in}\right\rbrack \;$$
#
#
# Let us begin the iterative solution:
#
# - $R_1(M=1)$
#
# $$r_d =R{\;}_1 -\phi \Delta t$$
# $$4\ldotp 8=R_1 -\phi \Delta t$$
# $$\phi =-5\ldotp 2\;\left\lbrack \frac{\textrm{in}}{\textrm{hr}}\right\rbrack \textrm{not feasible}$$
#
# - $R_1, R_2(M=2)$
#
# $$r{\;}_d =R{\;}_1 +R{\;}_2 -2\phi \Delta t$$
# $$4\ldotp 8=2\ldotp 2+2\ldotp 08-2\phi \times \;0\ldotp 5$$
# $$ \phi =-0\ldotp 52\;\left\lbrack \frac{\textrm{in}}{\textrm{hr}}\right\rbrack \textrm{not feasible}$$
#
# - $R_1, R_2, R_3(M=3)$
#
# $$r{\;}_d =R{\;}_1 +R{\;}_2 +R{\;}_3 -3\phi \Delta t$$
#
# $$ \phi =0\ldotp 27\left\lbrack \frac{\textrm{in}}{\left(0\ldotp 5\right)\textrm{hr}}\right\rbrack \ge R_4 =0\ldotp 26\left\lbrack \frac{\textrm{in}}{\left(0\ldotp 5\right)\textrm{hr}}\right\rbrack \; \textrm{\textbf{feasible!}}$$
#
# **Note:** If $\phi <R_4$ then we had to try $r{\;}_d =\sum_{i=1}^{M=4} \left(R{\;}_i -\phi \Delta t\right)$ and continue the process.
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F17.png" alt="Figure 17" style="width: 500px; height: auto;">
# </div>
#
# For characterizing the amount of excess rainfall from stream data, we can also calculate the **runoff coefficient** (C):
#
# $$C=\frac{r_d }{\sum_{i=1}^N R_i }=\frac{\textrm{Total}\;\textrm{runoff}}{\textrm{Rainfall}\;\textrm{after}\;\textrm{the}\;\textrm{beginning}\;\textrm{of}\;\textrm{runoff}}$$
#
# From the previous example, we can easily calculate the runoff coefficient as:
#
# $$C=\frac{4\ldotp 8\;\left\lbrack \textrm{in}\right\rbrack }{\left(1\ldotp 33+2\ldotp 2+2\ldotp 08+0\ldotp 2+0\ldotp 09\right)\;\left\lbrack \textrm{in}\right\rbrack }=0\ldotp 81$$
# ---

# %% [markdown]
# The **runoff coefficient** is used extensively in engineering practices to determine the peak flow rate of a storm event based on average rainfall intensity over small watersheds through the rational method:
#
# $$Q_p =\textrm{CiA}$$
#
# where $Q_p$ is the **peak flow rate** [cfs], $i$ is the design rainfall intensity $\left\lbrack \textrm{in}\;{\textrm{hr}}^{-1} \right\rbrack$, and $A$ is the basin area  $\left\lbrack \textrm{acres}\right\rbrack$. **Note that the dimensions for the rational method do not match and it is purely an empirical relationship**.  In practice, this method is used to design the size of catch basins and storm sewers by calculating the peak flow rate for a certain **return period** of the design rainfall event. There are standard estimates of the runoff coefficients based on different **soil types**, **land use** and **slopes**. For example for lawns (C=0.05-0.35), forest (0.05-0.25), concrete streets (0.7-0.95).

# %% [markdown]
# ___
#
# **Example Problem 6.2:** Consider a design problem where the peak discharge is required to size a storm drain inlet for a 2.4-acre parking area where the design rainfall intensity is 8.6 in/hr and the runoff coefficient of is 0.95.
#
# **Solutions**:
#
# $$Q_p =0\ldotp 95\times 8\ldotp 6\times 2\ldotp 4=20\;\left\lbrack {\textrm{ft}}^3 {\mathrm{s}}^{-1} \right\rbrack$$
# ---

# %% [markdown]
# Where drainage area is characterized by distinct subareas that can be characterized by different runoff coefficients, a weighted runoff coefficients should be determined. The weights are based on the area of each land use and is formed by the following equation.
#
# $$C_{w\;} =\frac{\;\sum_{j=1}^n C_j A_j }{\sum_{j=1}^n A_j }$$
#
#
# in which $A_j$ is the area for land cover $j$, $C_j$ is the runoff coefficient for area $j$, $n$ is the number of distinct land covers within the watershed and $C_w$ is the weighted mean runoff coefficient. Therofere, in this case the peak runoff is
#
# $$Q_p =i\sum_{j=1}^n C_j {\;A}_j =i\;C_w A$$
#
#
# where $A=\sum_{j=1}^n A_j$.

# %% [markdown]
# ___
#
# **Example Problem 6.3:** Compute the runoff for the following land use chracteristics in heterogenous basin for design rainfall of 3.6 $\left\lbrack \textrm{in}\;{\textrm{hr}}^{-1} \right\rbrack \ldotp$
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F18.png" alt="Figure 18" style="width: 500px; height: auto;">
# </div>
#
#
# **Solutions**:
#
# $$C_w =\frac{\;0\ldotp 19\times 14\ldotp 2+0\ldotp 14\times 11\ldotp 6+0\ldotp 32\times 8\ldotp 9+0\ldotp 82\times 3\ldotp 9}{42\ldotp 9}=0\ldotp 33$$
# $$Q_p =0\ldotp 33\times 3\ldotp 6\times 42\ldotp 9=51\;\left\lbrack {\textrm{ft}}^3 {\mathrm{s}}^{-1} \right\rbrack$$
#
#
# ---

# %% [markdown]
# ### 3-3-2 Excess Rainfall Using Infiltration Methods
#
# If streamflow data is not known, then we must resort to infiltration models to calculate the excess rainfall hyetograph. It is common to use infiltration models like **Green-Ampt** to estimate the ERH. The key assumption is that **Direct Runoff = Precipitation - Infiltration**.
#
# Recall that the Green-Ampt infiltration rate is defined as:
#
# $$f_t =K_{\textrm{sat}} \left(1+\frac{\left|\psi_f \right|\Delta \theta }{F_t }\right)$$
#
# where $f_t$ denotes changes of infiltration rate in time $t$ and $F_t$ is the cumulative infiltration from 0 to time *t*.  Additionally, we showed that the cumulative infiltration can be computed as follows after the ponding time:
#
#
# $$F_t =K_{\textrm{sat}} t+\left|\psi_f \right|\ldotp \Delta \theta \ldotp \ln \left(1+\frac{F_t }{\left|\psi_f \right|\Delta \theta }\right)$$
#
# Now for the purpose of creating the ERH, we must define cumulative infiltration after the ponding time. To that end, we showed that:
#
# $$F_{t_p +\Delta t} =F_{t_p } {+K}_{\textrm{sat}} \Delta t+\left|\psi_f \right|\ldotp \Delta \theta \ldotp \ln \left(\frac{F_{t_p +\Delta t} +\left|\psi_f \right|\ldotp \Delta \theta }{F_{t_p } +\left|\psi_f \right|\ldotp \Delta \theta }\right)$$
#
# Where the cumultive infiltration at the **time of ponding** ($t_p$), was defined as follows:
#
# $$F_{t_p } =\frac{K_{\textrm{sat}} \Delta \theta \left|\psi_f \right|}{p-K_{\textrm{sat}} }$$
#
# As described in the following, finding ERH using infiltration method is an iterative process.
#
# **Algorithm for determination of infiltration and ponding time under variable rainfall intensity:**
#
#  **WHILE** $t<t_r$ ($t_r$: the rainfall duration)
#
#  $$f_t =K_{\textrm{sat}} \left(1+\frac{\left|\psi_f \right|\Delta \theta }{F_t }\right)$$
#
# **If** infilteratoion rate is greater than precipitation ( $f_t >p_t$) (no ponding at time *t*)
#
# $$F_{t+\Delta t} =F_t +p_t \times \;\Delta t\;\;\;\;\;\;\;\;\to \;\;\;\;\;\;\;\;\;f_{t+\Delta t} {\;=\;K}_{\textrm{sat}} \left(1+\frac{\left|\psi_f \right|\Delta \theta }{F_{t+\Delta t} }\right)$$
#
# **ELSE** ponding occurres, when infiltration rate $f_t$ is smaller than precipitation rate $p_t$ ( $f_t <p_t$).
#
# $$F_{t+\Delta t} =F_t +K_{\textrm{sat}} \;\Delta t+\left|\psi_f \right|\Delta \theta \;\ln \left(\frac{F_{t+\Delta t} +\left|\psi_f \right|\Delta \theta }{F_t +\left|\psi_f \right|\Delta \theta }\right)$$
#
# $$f_{t+\Delta t} \;{=\;K}_{\textrm{sat}} \left(1+\frac{\left|\psi_f \right|\Delta \theta }{F_{t+\Delta t} }\right)$$
#
# **END**
#
# $t=t+\Delta t\;$

# %% [markdown]
# ___
#
# **Example Problem 6.4:** A rainfall hyetograph is given in col(1) and (2) of the following table. The soil is sandy loam with initial saturation $s=\frac{\theta_i }{\eta }=40%$, $|\psi_f |=11\ldotp 01\;\left\lbrack \textrm{cm}\right\rbrack$ and $\theta {\;}_{\textrm{sat}} =\eta \;$. Determine the excess rainfall hyetograph (ERH).
#
# **Solutions**:
#
# $$\Delta \theta =\left(1-s\right)\times \theta_{\textrm{sat}} \;=\theta {\;}_{\textrm{sat}} -\theta {\;}_i =0\ldotp 247\to \;\left|\psi_f \right|\times \;\Delta \theta =2\ldotp 72\;\left\lbrack -\right\rbrack \;\;\;\;\;\textrm{and}{\;\;\;\;\;K}_{\textrm{sat}} =1\ldotp 09\;\left\lbrack \textrm{cm}\;{\textrm{hr}}^{-1} \right\rbrack$$
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F19.png" alt="Figure 19" style="width: 1100px; height: auto;">
# </div>
#
# **Note: The fourth colume is column 3 times 60/10 to obtain hourly rainfall rate.**
#
# @ t=0 [min]
#
# $$F_0 =0,{\;f}_0 =\infty$$
#
# @ t=10 [min]
#
# $$f_{10} =K_{\textrm{sat}} \left(\frac{\left|\psi_f \right|\Delta \theta }{F_{10} }+1\right)=17\ldotp 57\;\left\lbrack \textrm{cm}\;{\textrm{hr}}^{-1} \right\rbrack$$
# $$f_{10} >\left(p_{10} =1\ldotp 26\;\left\lbrack \textrm{cm}\right\rbrack \right)\;\left(\textrm{no}\;\textrm{ponding}\right)$$
# $$F_{10} =0\ldotp 18\;\left\lbrack \textrm{cm}\right\rbrack \;\;\;\;\;\textrm{and}\;\;\;\;\;f_{10} =17\ldotp 57\;\left\lbrack \textrm{cm}{\;\textrm{hr}}^{-1} \right\rbrack$$
#
# The same process and calculatoin continue with no ponding, as shown in the following excel sheet, until
#
# @ t=60 [min]
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F20.png" alt="Figure 20" style="width: 1100px; height: auto;">
# </div>
#
# $$F_{60} =F_{50} +p_{50} \Delta t=1\ldotp 34+2\ldotp 58\times \;\frac{10}{60}=1\ldotp 77\;\left\lbrack \textrm{cm}\right\rbrack$$
#
# $$f_{60} =K_{\textrm{sat}} \left(\frac{\left|\psi_f \right|\Delta \theta }{F_{60} }+1\right)=1\ldotp 09\times \;\left(\frac{2\ldotp 72}{1\ldotp 77}+1\right)=2\ldotp 77<p_{60} =3\ldotp 84\;\left\lbrack \textrm{cm}{\;\textrm{hr}}^{-1} \right\rbrack \;\to \textrm{Ponding}\;\textrm{occurs}!!!$$
#
#
# We need to use the Green-Ampt formula for computation of $F_{70}$:
#
# $$F_{t+\Delta t} -F_t -\left|\psi_f \right|\Delta \theta \ln \left(\frac{F_{t+\Delta t} +\left|\psi_f \right|\ldotp \Delta \theta }{F_t +\left|\psi_f \right|\ldotp \Delta \theta }\right)=K_{\textrm{sat}} \Delta t$$
#
# $$F_{70} -F_{60} -2\ldotp 72\times \;\ln \left(\frac{F_{70} +2\ldotp 72}{F_{60} +2\ldotp 72}\right)=1\ldotp 09\times \frac{\;10}{60}$$
#
# $$F_{70} =2\ldotp 21\;\left\lbrack \textrm{cm}\right\rbrack$$
#
# $$f_{70} =K_{\textrm{sat}} \left(\frac{\left|\psi_f \right|\Delta \theta }{F_{70} }+1\right)=1\ldotp 09\times \;\left(\frac{2\ldotp 72}{2\ldotp 21}+1\right)=2\ldotp 43\;\left\lbrack \textrm{cm}{\;\textrm{hr}}^{-1} \right\rbrack$$
#
# Cumulative excess rainfall = cumulative rainfall - cumulative infiltration = 2.41(col 3) -2.21(col 6) = 0.2 [cm](col 7)
#
# After 140 [min], ponding ceases as ${\;f}_{140} =1\ldotp 74\;\left\lbrack \textrm{cm}{\;\textrm{hr}}^{-1} \right\rbrack >p_{140} =1\ldotp 68\;\left\lbrack \textrm{cm}{\;\textrm{hr}}^{-1} \right\rbrack$
#
# $$F_{t+\Delta t} =F_t +p_t \times \;\Delta t$$
#
# $$F_{150} =F_{140} +p_{140} \times \;\Delta t=4\ldotp 53+1\ldotp 68\times \;\frac{10}{60}=4\ldotp 81\;\left\lbrack \textrm{cm}\right\rbrack$$
#
# $$f_{150} =K_{\textrm{sat}} \left(\frac{\left|\psi_f \right|\Delta \theta }{F_{150} }+1\right)=1\ldotp 09\times \;\left(\frac{2\ldotp 72}{4\ldotp 85}+1\right)=1\ldotp 71\;\left\lbrack \textrm{cm}{\;\textrm{hr}}^{-1} \right\rbrack >p_{150} =1\ldotp 44\;\left\lbrack \textrm{cm}{\;\textrm{hr}}^{-1} \right\rbrack \;$$
#
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F21.png" alt="Figure 21" style="width: 1100px; height: auto;">
# </div>
#
# **Note: An excel file of the above calculation table is available in the class website.**
#
# Below is a plot showing the results of the example problem. Notice that all abstractions before the time of ponding (where surface runoff is generated) is labeled initial abstractions.  After $t_p$, everything above the green line is effective rainfall and everything below is infiltrated (losses).
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F22.png" alt="Figure 22" style="width: 500px; height: auto;">
# </div>
#
#
# <p style="text-align: center;">Solution plot to Green-Ampt example.</p>
#
# ---

# %% [markdown]
# ### 3-3-3 SCS Method for Runoff Calculation:
#
# The old USDA Soil Conservation Service (SCS; now called USDA-NRCS) developed a runoff estimation method based on the following hypothesis.
#
# $$\frac{\textrm{Infiltrated}\;\textrm{water}}{\textrm{Total}\;\textrm{retention}\;\textrm{capacity}}=\frac{\textrm{produced}\;\textrm{surface}\;\textrm{runoff}\;\left(\textrm{excess}\;\textrm{precipitaiton}\right)}{\textrm{Total}\;\textrm{available}\;\textrm{water}\;\textrm{for}\;\textrm{surface}\;\textrm{runoff}\;}$$
#
# $$\frac{F_a }{S}=\frac{P_e }{P-I_a \;}$$
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F23.png" alt="Figure 23" style="width: 400px; height: auto;">
# </div>
#
# <p style="text-align: center;">Schematic of the hydrograph components for the SCS method</p>
#
# - $P$: Total precipitation [m, in]
# - $I_a$: Initial abstraction [m, in]
# - $P_e$: Excess precipitation [m, in]
# - $F_a$: Water retained in the watershed [m, in]
# - $S$: Maximum retention storage [m, in]
# The above equation can be written as follows:
#
# $$\frac{P-P_e -I_{a\;} }{S}=\frac{P_e }{P-I_a \;}$$
#
# and thus
#
# $$P_{e\;} =\frac{{\left(P-I_{a\;} \right)}^{2\;} }{P-I_a +S}$$
#
# From data of field experiments for small watersheds, we can assume $I_a =0\ldotp 2S$, which leads to the following expression of excess precipitation:
#
# $$P_{e\;} =\frac{{\left(P-0\ldotp 2S\right)}^{2\;} }{P+0\ldotp 8S}$$
#
# Experimental results allowed parameterization of $S$ using a **curve number**, which describes the retention capacity of differing landscapes:
#
# $$ S=\frac{1000}{\textrm{CN}}-10 \;\;  [\textbf{inches}]$$
#
# where \textit{\textbf{CN}} is called the curve number $0\le \textrm{CN}\le 100$.
#
# *CN*=100 (Impervious surfaces, e.g., pavements)
#
# *CN*<100 (Natural surfaces)
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F24.png" alt="Figure 24" style="width: 600px; height: auto;">
# </div>
#
# <p style="text-align: center;">Solution of the SCS runoff equations for normal soil moisture condition (from U.S. Department of Agricultural Soil Conservation Service 1972)</p>
#
# The *CN* depends on:
#
# - The antecedent moisture condition (AMC)
# - Soil type
# - Land use
#
# The curve numbers in the above figure or available tables are for **normal antecedent moisture conditions (AMC II)**. The soil moisture conditions for SCS method are defined as follows:
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F25.png" alt="Figure 25" style="width: 500px; height: auto;">
# </div>
#
# <p style="text-align: center;">Definitions of AMC based on 5-day antecedent rainfall</p>
#
# Therefore, correction factors are necessary for the dry and wet conditions as follows:
#
# $$ \textrm{CN}\left(I\right)=\frac{4\ldotp 2\textrm{CN}\left(\textrm{II}\right)}{10-0\ldotp 058\textrm{CN}\left(\textrm{II}\right)}\;\left(\textrm{dry}\right) $$
#
# $$ \textrm{CN}\left(\textrm{III}\right)=\frac{23\textrm{CN}\left(\textrm{II}\right)}{10+0\ldotp 13\textrm{CN}\left(\textrm{II}\right)}\;\left(\textrm{wet}\right) $$
#
# The *CN(II)* values also depend on the soil type with four categories:
#
#
# - **Group A**: Deep sand, deep loess, aggregated silt (lower CN values, higher retention)
# - **Group B**: Shallow loess, sandy loam
# - **Group C**: Clay, loam, clayey loam
# - **Group D**: Soils with heavy content of clay (high CN values, low retention)
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F26a.png" alt="Figure 26a" style="width: 800px; height: auto;">
#   <img src="Figures/Ch6/Ch6F26b.png" alt="Figure 26b" style="width: 800px; height: auto;">
#   <img src="Figures/Ch6/Ch6F26c.png" alt="Figure 26c" style="width: 800px; height: auto;">
# </div>
#
# <p style="text-align: center;">Runoff curve numbers (average watershed condition, $I_a =0\ldotp 2S$, USDA, 1986)</p>
#
# The curve number in the above tables are for average size watersheds ($I_a =0\ldotp 2S$) and normal antecedent moisture condition (AMC II). **For watersheds with several sub-catchments with different CNs, the area-averaged composite values of CN shall be computed**.

# %% [markdown]
# ___
#
# **Example Problem 6.5:** Compute runoff from 5 inches of rainfall on a 1000-acre watershed. Hydrologic soil type is 50% (B) and 50%(C). The watershed land use is:
#
# - 80% residential area (40% soil type B, 40% soil type C) that is 30% impervious
# - 20% paved roads (10% soil type B, 10% soil type C) with curbs and storm sewers
#
#
# **Solutions**:
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F27.png" alt="Figure 27" style="width: 500px; height: auto;">
# </div>
#
#
# $$\textrm{CN}\left(\textrm{II}\right)=\frac{40\times \;72+10\times \;98+40\times \;81+10\times \;98}{40+10+40+10}=80\ldotp 8$$
# $$S=\frac{1000}{\textrm{CN}\;\left(\textrm{II}\right)}-10=2\ldotp 38\;\left\lbrack \textrm{in}\right\rbrack$$
# $$P_e =\frac{{\left(P-0\ldotp 2S\right)}^{2\;} }{P+0\ldotp 8S}=2\ldotp 96\;\left\lbrack \textrm{in}\right\rbrack$$
#
# for wet condition:
#
# $$\textrm{CN}\left(\textrm{III}\right)=\frac{23\times \textrm{CN}\left(\textrm{II}\right)}{10+13\times \;\textrm{CN}\left(\textrm{II}\right)}=90\ldotp 6$$
#
# and then we an compute $S$ and $P_e$ for this new curve number to account for anrecedent soil wetness.
#
# ---

# %% [markdown]
# # 5- Runoff Hydraulics
#
# Surface runoff in a watershed occurs first as a **thin sheet of overland flow** in the upper slopes for a short distance (< 100 ft) and then eventually produce or merge to the channel flow that you see in gullies, streams and rivers. The goal for this section is to briefly quantify the properties of overland sheet flow.
#
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F28.png" alt="Figure 28" style="width: 800px; height: auto;">
# </div>
#
# <p style="text-align: center;">Overland flow to the streams and modeling concepts</p>
#
# Here $p$ is precipitation intensity $\left\lbrack \textrm{mm}\;{\textrm{hr}}^{-1} \right\rbrack$ or $\left\lbrack \textrm{in}\;{\textrm{hr}}^{-1} \right\rbrack$, $\theta$ is the slope angle, $f_i$ is infiltration rate $\left\lbrack \textrm{mm}\;{\textrm{hr}}^{-1} \right\rbrack$ or $\left\lbrack \textrm{in}\;{\textrm{hr}}^{-1} \right\rbrack$, $V$ is average velocity $\left\lbrack {\mathrm{m}\;\mathrm{s}}^{-1} \right\rbrack$, $L$ is slope length $\left\lbrack \mathrm{m}\right\rbrack$, and $y$ is the flow depth $\left\lbrack \textrm{cm}\right\rbrack$.
#
#
# Let's write a mass balance or **continuity equation** for the above control volume as follows:
#
# - **Inflow**: $p\;L\;\cos \theta \;$(precipitation)
# - **Outflow 1**: $f_i \;L\;\cos \theta \;$(infiltration)
# - **Outflow 2**: $q_0 =\textrm{Vy}\;\;$(discharge per unit width)
#
# Conservation of mass (inflow  =  sum of outflows) results in
#
# $$p\;L\;\cos \theta =f_i \;L\;\cos \theta +\textrm{Vy}$$
#
# Recall that from the **Darcy-Weisbach** equation, we have
#
# $$h_f =f\frac{L}{D}\frac{V^2 }{2g}\;$$
#
#
# - $f$: friction coefficient
# - $L$ : pipe length
# - $D$ : pipe diameter
# - $V$: velocity
# - $h_f$: head loss.
#
# By definition, the **hydraulic radius** in a pipe or a channel is defined as $R=\frac{A}{P}$
#
# $A:$ wetted area [$\left.{\mathrm{L}}^2 \right\rbrack$
#
# $P:$ wetted perimeter [$\left.\mathrm{L}\right\rbrack$
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F29.png" alt="Figure 29" style="width: 500px; height: auto;">
# </div>
#
# For example, for a rectangular channel we have $R=\frac{\textrm{by}}{b+2y}\approx y$ (when $b\gg 2y$).
#
# Recall that for a pipe $R=\frac{\pi \frac{D^2 }{4}}{\pi D}=\frac{D}{4}$ and thus $D=4R$, when the the Darcy-Weisbach equation is used for a rectangular channel
#
# $$h_f =f\frac{L}{4R}\frac{\;V^2 }{2g}$$

# %% [markdown]
# ## 5-1 Laminar Overland Flow
#
# Next we need to use the conservation of momentum to define the average velocity and height of the overland sheet flow.  These equations depend on whether flow is **laminar** (parallel streamlines) or **turbulent** (mixed by eddies), which can be determined by the flow **Reynold's number**:
#
# $$\textrm{Re}=\frac{\textrm{VD}}{\nu }=\frac{4\textrm{VR}}{\nu }\;\; \textrm{(pipe)}\;\;\;   \textrm{Re}=\frac{4\textrm{Vy}}{\nu }=\frac{4q_0 }{\nu }\;\; (\textrm{wide rectangular channel})$$
#
# where $\nu$ is kinematic viscosity $\left\lbrack {\mathrm{m}}^2 {\mathrm{s}}^{-1} \right\rbrack$.
#
# We know from fluid mechanics that generally the flow is laminar when $\textrm{Re}<2000$. Recall that from the **Moody diagram**, we have $f=\frac{64}{\textrm{Re}}$ for **laminar flow** in pipes; however, for uniform laminar overland sheet flow, the following formula shall be used (Chow 1998):
#
# $$f=\frac{C_L }{\textrm{Re}}$$
#
# $$C_L=96+108p^{0\ldotp 4}$$
#
# where $p$ is  the precipitation rate [$\textrm{in}{\;\textrm{hr}}^{-1}$].
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F30.png" alt="Figure 30" style="width: 500px; height: auto;">
# </div>
#
# Recall that the **Energy Grade Line (EGL)** is
#
# $$\textrm{EGL}=z+\frac{V^2 }{2g}+\frac{P}{\rho_w g}$$
#
# and for a uniform flow, we have $S_f =S_w =S_0 =\frac{h_f }{L}$, where $S_f$ is the slope of the $\textrm{EGL}$, $h_f$ is the head loss over the horizontal length $L$.
#
# From the Darcy-Weisbach equation, for a uniform flow, $S_f =S_w =S_0 =\frac{h_f }{L}=\frac{f}{4y}\frac{V^2 }{2g}$ and $q_0 =\textrm{Vy},$ then we have
#
# $$S_0 =\frac{f}{4y}\frac{q_0^2 }{2gy^2 }=\frac{f}{8gy^3 }q_0^2$$
#
# $$y^3 =\frac{f}{8gs_0 }q_0^2 \Longrightarrow y={\left(\frac{fq_0^2 }{8gS_0 }\right)}^{1/3}$$
#
# where $q_0 =(p-f_i )\,L\cos \,\theta$.

# %% [markdown]
# ## 5-2 Turbulent Overland Flow
#
# Once overland flow becomes turbulent ($\textrm{Re}>$ 2000), the roughness factor $f$ becomes independent of the Reynolds number, and the **Manning's equation** shall be used to explain the velocity of overland sheet flow as follows:
#
# $$V=\frac{1.49}{n}R^{2/3} S_0^{1/2} ~~~~({\mathrm{E}\mathrm{n}\mathrm{g}\mathrm{l}\mathrm{i}\mathrm{s}\mathrm{h}\;\mathrm{u}\mathrm{n}\mathrm{i}\mathrm{t}\mathrm{s}})~~~~V=\frac{1}{n}R^{2/3} S_0^{1/2} ~~~~{(\mathrm{S}\mathrm{I}\;\mathrm{u}\mathrm{n}\mathrm{i}\mathrm{t}\mathrm{s})},$$
#
# where $n$ is Manning's roughness coefficient and $R=y$ is the hydraulic radius for a wide open channel. The **Manning coefficient,** is an empirically derived coefficient, which is dependent on many factors, including **surface roughness** and **channel sinuosity**.
#
# Substitute $V=\frac{q_0 }{y}$ into Manning's equation one can obtain:
#
#
# $$y={\left(\frac{nq_0 }{1.49S_0^{1/2} }\right)}^{3/5} ~~~~({\mathrm{E}\mathrm{n}\mathrm{g}\mathrm{l}\mathrm{i}\mathrm{s}\mathrm{h}\;\mathrm{u}\mathrm{n}\mathrm{i}\mathrm{t}\mathrm{s}})~~~~y={\left(\frac{nq_0 }{S_0^{1/2} }\right)}^{3/5} ~~~~({\mathrm{S}\mathrm{I}\;\mathrm{u}\mathrm{n}\mathrm{i}\mathrm{t}\mathrm{s}}).$$
#
# Typical values for the Manning's coefficients $n$ for **overland flow** are given on the next slide. These values are valid for sheet flow with depths less than 0.1 ft. We will revisit the Manning equation in the next chapters.
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F31.png" alt="Figure 31" style="width: 500px; height: auto;">
# </div>
# <p style="text-align: center;">Typical values of the Manning roughness coefficient (n) for overland sheet flow</p>
#
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F32.png" alt="Figure 32" style="width: 500px; height: auto;">
# </div>
# <p style="text-align: center;">Hydraulic radius formulas for simple open channel geometries. These formulas will be revisited in the next chapters</p>

# %% [markdown]
# ## 5-3 Travel Time
#
# One main reason for defining the velocity of these runoff mechanisms is to determine the **travel time** in a basin.  As we know, for different segments of the river with the same velocity, the travel time can be approximated as follows:
#
# $$ \triangle t = \sum_{i=1}^{N} \frac{l_{i}}{V_{i}} $$
#
# Every point within a watershed will have a travel time based on its flowpath to the outlet.  When rainfall begins, the areas with the shortest travel times are contributing first to the outflow. As the storm progresses, larger areas of the watershed contribute to the outflow **until the time when all areas in the watershed are contributing to flow at the outlet**. This time scale is known as the **time of concentration** ($t_c$) and can also be defined as the **travel time of precipitation water from the longest flow path to the outlet**.
#
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F33.png" alt="Figure 33" style="width: 500px; height: auto;">
# </div>
#
# <p style="text-align: center;">Schematic showing the growing contributing areas and the time of concentration</p>
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F34.png" alt="Figure 34" style="width: 500px; height: auto;">
# </div>
#
# <p style="text-align: center;">Approximate average velocities in $\mathrm{[fts^{-1}]}$ of runoff flow for calculating time of concentration. The unconcentrated condition addresses the flow velocity in the upper part of the watershed prior to the overland flows accumulating in a channel, while concentrated condition refers to the flow velocity in a channel network (From drainage manual, Texas highway department, 1970).</p>

# %% [markdown]
# ___
#
# **Example Problem 6.6:**   Calculate the time of concentration of a watershed in which, the longest flow path covers 100 $\left\lbrack \textrm{ft}\right\rbrack$ of pasture at slope 5\% and a 1000 $\left\lbrack \textrm{ft}\right\rbrack$ long rectangular channel having 2 $\left\lbrack \textrm{ft}\right\rbrack$ width with Manning coefficient $n=0\ldotp 015$ and slope of the chennel is $S_0 =2\ldotp 5$\%. The channel receives a lateral flow of 0.0096 $\left\lbrack \textrm{cfs}\;{\textrm{ft}}^{-1} \right\rbrack$.
#
# The flow velocity is 3 $\left\lbrack \textrm{ft}\;{\mathrm{s}}^{-1} \right\rbrack$ for the 100 $\left\lbrack \textrm{ft}\right\rbrack$ of pasture with slope 5\% (see the above Table) and thus $\Delta t_1 =33\;\mathrm{s}$.
#
#
# **Solutions**:
#
# For the rectangular channel with length 1000 $\left\lbrack \textrm{ft}\right\rbrack$, we have
#
# $$q_0 =0.0096\,\,{[\mathrm{cfs\;ft^{-1}} ]},\;n=0.015\textrm{,}\;S_0 =2.5\% \textrm{,} \;\;\mathrm{L=1000[ft]}  \textrm{,}\;\; \mathrm{b=2[ft]} $$
#
# The total discharge for segment $L_i$ is $\;Q_i =q_0 L_i$ and $Q=\frac{1.49}{n}S_0^{1/2} AR^{2/3} =\frac{1.49}{n}S_0^{1/2} (by){\left(\frac{by}{b+2y}\right)}^{2/3}$ . Thus, after finding $y$ from the Manning equation, we can compute $V_i =\frac{Q_i }{\textrm{by}}$.
#
# We solve the problem for river segments $L_i =200$ $\left\lbrack \textrm{ft}\right\rbrack$ in the following table:
#
# <div style="text-align: center;">
#   <img src="Figures/Ch6/Ch6F35.png" alt="Figure 35" style="width: 500px; height: auto;">
# </div>
#
# For example, for the first segement $Q=q_0 \times L_i =0\ldotp 0096\times 200=1\ldotp 92$. The depth of the flow in third row of the table is obtained by solving for the root of the Manning equation for a rectangular channel $1\ldotp 92=\frac{\;1\ldotp 49}{0\ldotp 015}\times \frac{\;2\ldotp 5}{100}\times \left(2\times y\right)\times {\left(\frac{\;2y}{2+2y}\right)}^{\frac{2}{3}}$. The depth are calculated for the flow rate in the second row for $b=2$ ft. After calculating the depth, we caculate the velocity as $V_i =\frac{Q_i }{b\times \;y_i }$.
#
# The $V_m =\frac{\;\left(V_i +V_{i+1} \right)}{2}$ represents the average velocity over each stream interval. For example, $V_m =(4.88+6.21)/2=5.55$ $\left\lbrack \textrm{ft}\;{\mathrm{s}}^{-1} \right\rbrack$ for the second segment.
#
#
# ---
